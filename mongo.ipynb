# %% [markdown]
# # Set up

# %% [markdown]
# ## Imports

# %%
import json

from bson import SON

import logger_setup
import logging
import pymongo
from pymongo import MongoClient, GEO2D
from pymongo.database import Database, Collection
from csv_reader import ais_csv_to_gdf, split_df_by_batch_size

# %%
logger_setup.setup_logger(level=logging.INFO)
logger = logging.getLogger()

# %% [markdown]
# # Code

# %% [markdown]
# ### Create geojson

# %%
main_gdf = ais_csv_to_gdf("data/AIS_2020_12_31.csv")
main_gdf['BaseDateTime'] = main_gdf['BaseDateTime'].dt.strftime('%Y-%m-%d %H:%M:%S')

gdfs = split_df_by_batch_size(main_gdf, 1_000_000)
# for gdf in gdfs:
#     # geojson = tgdf._to_geo(drop_id=True)
#     geojson = gdf.to_geo_dict(drop_id=True)
#     print(len(geojson["features"]))
# print(geojson["features"])
# Out:
# 1000000
# 1000000
# 1000000
# 1000000
# 1000000
# 1000000
# 420411

# %%
mongo_url = "mongodb://localhost:55001/"
database_name = "temp"
collection_name = "temp"

# %%
client: MongoClient = MongoClient(mongo_url)
db: Database = client[database_name]
collection: Collection = db[collection_name]

collection.drop()
# Out:
# 2024-05-07 19:46:13,590 - INFO: {"message": "Waiting for suitable server to become available", "selector": "<function writable_server_selector at 0x78dfce6a2560>", "operation": "drop", "topologyDescription": "<TopologyDescription id: 663a68e5e7a0f2055d7df16a, topology_type: Unknown, servers: [<ServerDescription ('localhost', 55000) server_type: Unknown, rtt: None>]>", "clientId": {"$oid": "663a68e5e7a0f2055d7df16a"}, "remainingTimeMS": 29}

# %% [markdown]
# ### Insert into database

# %%
client: MongoClient = MongoClient(mongo_url)
db: Database = client[database_name]
collection: Collection = db[collection_name]

for i, gdf in enumerate(gdfs):
    print(f"Processing {i + 1} / {len(gdfs)} geodataframe.")
    collection.insert_many(gdf.to_geo_dict(drop_id=True)["features"])

client.close()
# Out:
# Processing 1 / 7 geodataframe.
# Processing 2 / 7 geodataframe.
# Processing 3 / 7 geodataframe.
# Processing 4 / 7 geodataframe.
# Processing 5 / 7 geodataframe.
# Processing 6 / 7 geodataframe.
# Processing 7 / 7 geodataframe.

# %% [markdown]
# ### Create spatial index

# %%
client: MongoClient = MongoClient(mongo_url)
db: Database = client[database_name]
collection: Collection = db[collection_name]

collection.create_index([("geometry.coordinates", GEO2D)])

client.close()
# Out:
# 2024-05-07 20:06:13,543 - INFO: {"message": "Waiting for suitable server to become available", "selector": "<function writable_server_selector at 0x78dfce6a2560>", "operation": "createIndexes", "topologyDescription": "<TopologyDescription id: 663a6d95e7a0f2055ddfe92c, topology_type: Unknown, servers: [<ServerDescription ('localhost', 55000) server_type: Unknown, rtt: None>]>", "clientId": {"$oid": "663a6d95e7a0f2055ddfe92c"}, "remainingTimeMS": 29}

# %% [markdown]
# ### Retreive from database

# %%
search_location = [-87.68, 41.85]

# %%
from pprint import pprint

client: MongoClient = MongoClient(mongo_url)
db: Database = client[database_name]
collection: Collection = db[collection_name]

# query = {"geometry.coordinates": {"$within": {"$center": [search_location, 10]}}}
query = {"geometry.coordinates": SON([("$near", search_location), ("$maxDistance", 10)])}

results = list(collection.find(query, {'_id': False}).limit(1000))

for doc in results:
    pprint(doc)

client.close()
# Out:
# 2024-05-07 20:42:05,936 - INFO: {"message": "Waiting for suitable server to become available", "selector": "Primary()", "operation": "find", "topologyDescription": "<TopologyDescription id: 663a75fde7a0f2055ddfe944, topology_type: Unknown, servers: [<ServerDescription ('localhost', 55001) server_type: Unknown, rtt: None>]>", "clientId": {"$oid": "663a75fde7a0f2055ddfe944"}, "remainingTimeMS": 29}
# {'geometry': {'coordinates': [-87.6754, 41.84179], 'type': 'Point'},
#  'properties': {'BaseDateTime': '2020-12-31 21:59:59',
#                 'COG': 53.4,
#                 'CallSign': 'WDJ6110',
#                 'Cargo': None,
#                 'Draft': None,
#                 'Heading': 511.0,
#                 'IMO': None,
#                 'LAT': 41.84179,
#                 'LON': -87.6754,
#                 'Length': None,
#                 'MMSI': 367794470,
#                 'SOG': 3.8,
#                 'Status': 15.0,
#                 'TransceiverClass': 'A',
#                 'VesselName': 'GWYNETH ANNE',
#                 'VesselType': 31.0,
#                 'Width': None},
#  'type': 'Feature'}
# {'geometry': {'coordinates': [-87.67538, 41.84177], 'type': 'Point'},
#  'properties': {'BaseDateTime': '2020-12-31 23:01:46',
#                 'COG': 57.3,
#                 'CallSign': 'WDH6184',
#                 'Cargo': None,
#                 'Draft': None,
#                 'Heading': 60.0,
#                 'IMO': None,
#                 'LAT': 41.84177,
#                 'LON': -87.67538,
#                 'Length': 22.0,
#                 'MMSI': 367635370,
#                 'SOG': 5.7,
#                 'Status': 15.0,
#                 'TransceiverClass': 'A',
#                 'VesselName': 'SYDNEY REESE',
#                 'VesselType': 31.0,
#                 'Width': None},
#  'type': 'Feature'}
# {'geometry': {'coordinates': [-87.67557, 41.84166], 'type': 'Point'},
#  'properties': {'BaseDateTime': '2020-12-31 14:47:05',
#                 'COG': 51.5,
#                 'CallSign': 'WDJ6110',
#                 'Cargo': None,
#                 'Draft': None,
#                 'Heading': 57.0,
#                 'IMO': None,
#                 'LAT': 41.84166,
#                 'LON': -87.67557,
#                 'Length': None,
#                 'MMSI': 367794470,
#                 'SOG': 4.5,
#                 'Status': 15.0,
#                 'TransceiverClass': 'A',
#                 'VesselName': 'GWYNETH ANNE',
#                 'VesselType': 31.0,
#                 'Width': None},
#  'type': 'Feature'}
# {'geometry': {'coordinates': [-87.67625, 41.84128], 'type': 'Point'},
#  'properties': {'BaseDateTime': '2020-12-31 20:21:21',
#                 'COG': 231.6,
#                 'CallSign': 'WDJ6110',
#                 'Cargo': None,
#                 'Draft': None,
#                 'Heading': 511.0,
#                 'IMO': None,
#                 'LAT': 41.84128,
#                 'LON': -87.67625,
#                 'Length': None,
#                 'MMSI': 367794470,
#                 'SOG': 5.9,
#                 'Status': 15.0,
#                 'TransceiverClass': 'A',
#                 'VesselName': 'GWYNETH ANNE',
#                 'VesselType': 31.0,
#                 'Width': None},
#  'type': 'Feature'}
# {'geometry': {'coordinates': [-87.67705, 41.84081], 'type': 'Point'},
#  'properties': {'BaseDateTime': '2020-12-31 23:50:22',
#                 'COG': 229.2,
#                 'CallSign': 'WDH6184',
#                 'Cargo': None,
#                 'Draft': None,
#                 'Heading': 234.0,
#                 'IMO': None,
#                 'LAT': 41.84081,
#                 'LON': -87.67705,
#                 'Length': 22.0,
#                 'MMSI': 367635370,
#                 'SOG': 5.3,
#                 'Status': 15.0,
#                 'TransceiverClass': 'A',
#                 'VesselName': 'SYDNEY REESE',
#                 'VesselType': 31.0,
#                 'Width': None},
#  'type': 'Feature'}
# {'geometry': {'coordinates': [-87.67632, 41.84105], 'type': 'Point'},
#  'properties': {'BaseDateTime': '2020-12-31 21:58:59',
#                 'COG': 27.3,
#                 'CallSign': 'WDJ6110',
#                 'Cargo': None,
#                 'Draft': None,
#                 'Heading': 511.0,
#                 'IMO': None,
#                 'LAT': 41.84105,
#                 'LON': -87.67632,
#                 'Length': None,
#                 'MMSI': 367794470,
#                 'SOG': 3.1,
#                 'Status': 15.0,
#                 'TransceiverClass': 'A',
#                 'VesselName': 'GWYNETH ANNE',
#                 'VesselType': 31.0,
#                 'Width': None},
#  'type': 'Feature'}
# {'geometry': {'coordinates': [-87.67681, 41.84083], 'type': 'Point'},
#  'properties': {'BaseDateTime': '2020-12-31 14:46:02',
#                 'COG': 47.3,
#                 'CallSign': 'WDJ6110',
#                 'Cargo': None,
#                 'Draft': None,
#                 'Heading': 50.0,
#                 'IMO': None,
#                 'LAT': 41.84083,
#                 'LON': -87.67681,
#                 'Length': None,
#                 'MMSI': 367794470,
#                 'SOG': 3.8,
#                 'Status': 15.0,
#                 'TransceiverClass': 'A',
#                 'VesselName': 'GWYNETH ANNE',
#                 'VesselType': 31.0,
#                 'Width': None},
#  'type': 'Feature'}
# {'geometry': {'coordinates': [-87.67393, 41.8424], 'type': 'Point'},
#  'properties': {'BaseDateTime': '2020-12-31 22:01:10',
#                 'COG': 58.8,
#                 'CallSign': 'WDJ6110',
#                 'Cargo': None,
#                 'Draft': None,
#                 'Heading': 511.0,
#                 'IMO': None,
#                 'LAT': 41.8424,
#                 'LON': -87.67393,
#                 'Length': None,
#                 'MMSI': 367794470,
#                 'SOG': 3.9,
#                 'Status': 15.0,
#                 'TransceiverClass': 'A',
#                 'VesselName': 'GWYNETH ANNE',
#                 'VesselType': 31.0,
#                 'Width': None},
#  'type': 'Feature'}
# {'geometry': {'coordinates': [-87.6739, 41.84235], 'type': 'Point'},
#  'properties': {'BaseDateTime': '2020-12-31 14:48:12',
#                 'COG': 63.2,
#                 'CallSign': 'WDJ6110',
#                 'Cargo': None,
#                 'Draft': None,
#                 'Heading': 59.0,
#                 'IMO': None,
#                 'LAT': 41.84235,
#                 'LON': -87.6739,
#                 'Length': None,
#                 'MMSI': 367794470,
#                 'SOG': 4.7,
#                 'Status': 15.0,
#                 'TransceiverClass': 'A',
#                 'VesselName': 'GWYNETH ANNE',
#                 'VesselType': 31.0,
#                 'Width': None},
#  'type': 'Feature'}
# {'geometry': {'coordinates': [-87.6737, 41.84248], 'type': 'Point'},
#  'properties': {'BaseDateTime': '2020-12-31 20:20:00',
#                 'COG': 240.8,
#                 'CallSign': 'WDJ6110',
#                 'Cargo': None,
#                 'Draft': None,
#                 'Heading': 511.0,
#                 'IMO': None,
#                 'LAT': 41.84248,
#                 'LON': -87.6737,
#                 'Length': None,
#                 'MMSI': 367794470,
#                 'SOG': 6.1,
#                 'Status': 15.0,
#                 'TransceiverClass': 'A',
#                 'VesselName': 'GWYNETH ANNE',
#                 'VesselType': 31.0,
#                 'Width': None},
#  'type': 'Feature'}
# {'geometry': {'coordinates': [-87.6736, 41.84256], 'type': 'Point'},
#  'properties': {'BaseDateTime': '2020-12-31 23:48:16',
#                 'COG': 239.9,
#                 'CallSign': 'WDH6184',
#                 'Cargo': None,
#                 'Draft': None,
#                 'Heading': 239.0,
#                 'IMO': None,
#                 'LAT': 41.84256,
#                 'LON': -87.6736,
#                 'Length': 22.0,
#                 'MMSI': 367635370,
#                 'SOG': 5.3,
#                 'Status': 15.0,
#                 'TransceiverClass': 'A',
#                 'VesselName': 'SYDNEY REESE',
#                 'VesselType': 31.0,
#                 'Width': None},
#  'type': 'Feature'}
# {'geometry': {'coordinates': [-87.67709, 41.84048], 'type': 'Point'},
#  'properties': {'BaseDateTime': '2020-12-31 21:56:40',
#                 'COG': 224.9,
#                 'CallSign': 'WDJ6110',
#                 'Cargo': None,
#                 'Draft': None,
#                 'Heading': 511.0,
#                 'IMO': None,
#                 'LAT': 41.84048,
#                 'LON': -87.67709,
#                 'Length': None,
#                 'MMSI': 367794470,
#                 'SOG': 1.1,
#                 'Status': 15.0,
#                 'TransceiverClass': 'A',
#                 'VesselName': 'GWYNETH ANNE',
#                 'VesselType': 31.0,
#                 'Width': None},
#  'type': 'Feature'}
# {'geometry': {'coordinates': [-87.67835, 41.84014], 'type': 'Point'},
#  'properties': {'BaseDateTime': '2020-12-31 20:22:29',
#                 'COG': 240.7,
#                 'CallSign': 'WDJ6110',
#                 'Cargo': None,
#                 'Draft': None,
#                 'Heading': 511.0,
#                 'IMO': None,
#                 'LAT': 41.84014,
#                 'LON': -87.67835,
#                 'Length': None,
#                 'MMSI': 367794470,
#                 'SOG': 6.0,
#                 'Status': 15.0,
#                 'TransceiverClass': 'A',
#                 'VesselName': 'GWYNETH ANNE',
#                 'VesselType': 31.0,
#                 'Width': None},
#  'type': 'Feature'}
# {'geometry': {'coordinates': [-87.67659, 41.84058], 'type': 'Point'},
#  'properties': {'BaseDateTime': '2020-12-31 21:55:30',
#                 'COG': 292.4,
#                 'CallSign': 'WDJ6110',
#                 'Cargo': None,
#                 'Draft': None,
#                 'Heading': 511.0,
#                 'IMO': None,
#                 'LAT': 41.84058,
#                 'LON': -87.67659,
#                 'Length': None,
#                 'MMSI': 367794470,
#                 'SOG': 0.8,
#                 'Status': 15.0,
#                 'TransceiverClass': 'A',
#                 'VesselName': 'GWYNETH ANNE',
#                 'VesselType': 31.0,
#                 'Width': None},
#  'type': 'Feature'}
# {'geometry': {'coordinates': [-87.67777, 41.84023], 'type': 'Point'},
#  'properties': {'BaseDateTime': '2020-12-31 14:44:55',
#                 'COG': 59.8,
#                 'CallSign': 'WDJ6110',
#                 'Cargo': None,
#                 'Draft': None,
#                 'Heading': 50.0,
#                 'IMO': None,
#                 'LAT': 41.84023,
#                 'LON': -87.67777,
#                 'Length': None,
#                 'MMSI': 367794470,
#                 'SOG': 2.2,
#                 'Status': 15.0,
#                 'TransceiverClass': 'A',
#                 'VesselName': 'GWYNETH ANNE',
#                 'VesselType': 31.0,
#                 'Width': None},
#  'type': 'Feature'}
# {'geometry': {'coordinates': [-87.67278, 41.84287], 'type': 'Point'},
#  'properties': {'BaseDateTime': '2020-12-31 23:03:12',
#                 'COG': 61.5,
#                 'CallSign': 'WDH6184',
#                 'Cargo': None,
#                 'Draft': None,
#                 'Heading': 62.0,
#                 'IMO': None,
#                 'LAT': 41.84287,
#                 'LON': -87.67278,
#                 'Length': 22.0,
#                 'MMSI': 367635370,
#                 'SOG': 5.6,
#                 'Status': 15.0,
#                 'TransceiverClass': 'A',
#                 'VesselName': 'SYDNEY REESE',
#                 'VesselType': 31.0,
#                 'Width': None},
#  'type': 'Feature'}
# {'geometry': {'coordinates': [-87.6768, 41.84036], 'type': 'Point'},
#  'properties': {'BaseDateTime': '2020-12-31 21:57:50',
#                 'COG': 53.9,
#                 'CallSign': 'WDJ6110',
#                 'Cargo': None,
#                 'Draft': None,
#                 'Heading': 511.0,
#                 'IMO': None,
#                 'LAT': 41.84036,
#                 'LON': -87.6768,
#                 'Length': None,
#                 'MMSI': 367794470,
#                 'SOG': 1.4,
#                 'Status': 15.0,
#                 'TransceiverClass': 'A',
#                 'VesselName': 'GWYNETH ANNE',
#                 'VesselType': 31.0,
#                 'Width': None},
#  'type': 'Feature'}
# {'geometry': {'coordinates': [-87.6769, 41.84028], 'type': 'Point'},
#  'properties': {'BaseDateTime': '2020-12-31 21:47:00',
#                 'COG': 85.6,
#                 'CallSign': 'WDJ6110',
#                 'Cargo': None,
#                 'Draft': None,
#                 'Heading': 511.0,
#                 'IMO': None,
#                 'LAT': 41.84028,
#                 'LON': -87.6769,
#                 'Length': None,
#                 'MMSI': 367794470,
#                 'SOG': 3.6,
#                 'Status': 15.0,
#                 'TransceiverClass': 'A',
#                 'VesselName': 'GWYNETH ANNE',
#                 'VesselType': 31.0,
#                 'Width': None},
#  'type': 'Feature'}
# {'geometry': {'coordinates': [-87.67648, 41.84042], 'type': 'Point'},
#  'properties': {'BaseDateTime': '2020-12-31 21:54:11',
#                 'COG': 327.8,
#                 'CallSign': 'WDJ6110',
#                 'Cargo': None,
#                 'Draft': None,
#                 'Heading': 511.0,
#                 'IMO': None,
#                 'LAT': 41.84042,
#                 'LON': -87.67648,
#                 'Length': None,
#                 'MMSI': 367794470,
#                 'SOG': 0.4,
#                 'Status': 15.0,
#                 'TransceiverClass': 'A',
#                 'VesselName': 'GWYNETH ANNE',
#                 'VesselType': 31.0,
#                 'Width': None},
#  'type': 'Feature'}
# {'geometry': {'coordinates': [-87.67897, 41.83984], 'type': 'Point'},
#  'properties': {'BaseDateTime': '2020-12-31 21:45:51',
#                 'COG': 66.1,
#                 'CallSign': 'WDJ6110',
#                 'Cargo': None,
#                 'Draft': None,
#                 'Heading': 511.0,
#                 'IMO': None,
#                 'LAT': 41.83984,
#                 'LON': -87.67897,
#                 'Length': None,
#                 'MMSI': 367794470,
#                 'SOG': 5.7,
#                 'Status': 15.0,
#                 'TransceiverClass': 'A',
#                 'VesselName': 'GWYNETH ANNE',
#                 'VesselType': 31.0,
#                 'Width': None},
#  'type': 'Feature'}
# {'geometry': {'coordinates': [-87.67249, 41.843], 'type': 'Point'},
#  'properties': {'BaseDateTime': '2020-12-31 22:02:19',
#                 'COG': 61.8,
#                 'CallSign': 'WDJ6110',
#                 'Cargo': None,
#                 'Draft': None,
#                 'Heading': 511.0,
#                 'IMO': None,
#                 'LAT': 41.843,
#                 'LON': -87.67249,
#                 'Length': None,
#                 'MMSI': 367794470,
#                 'SOG': 3.8,
#                 'Status': 15.0,
#                 'TransceiverClass': 'A',
#                 'VesselName': 'GWYNETH ANNE',
#                 'VesselType': 31.0,
#                 'Width': None},
#  'type': 'Feature'}
# {'geometry': {'coordinates': [-87.67843, 41.83984], 'type': 'Point'},
#  'properties': {'BaseDateTime': '2020-12-31 14:43:52',
#                 'COG': 55.0,
#                 'CallSign': 'WDJ6110',
#                 'Cargo': None,
#                 'Draft': None,
#                 'Heading': 50.0,
#                 'IMO': None,
#                 'LAT': 41.83984,
#                 'LON': -87.67843,
#                 'Length': None,
#                 'MMSI': 367794470,
#                 'SOG': 2.0,
#                 'Status': 15.0,
#                 'TransceiverClass': 'A',
#                 'VesselName': 'GWYNETH ANNE',
#                 'VesselType': 31.0,
#                 'Width': None},
#  'type': 'Feature'}
# {'geometry': {'coordinates': [-87.67641, 41.84033], 'type': 'Point'},
#  'properties': {'BaseDateTime': '2020-12-31 21:53:00',
#                 'COG': 310.7,
#                 'CallSign': 'WDJ6110',
#                 'Cargo': None,
#                 'Draft': None,
#                 'Heading': 511.0,
#                 'IMO': None,
#                 'LAT': 41.84033,
#                 'LON': -87.67641,
#                 'Length': None,
#                 'MMSI': 367794470,
#                 'SOG': 0.3,
#                 'Status': 15.0,
#                 'TransceiverClass': 'A',
#                 'VesselName': 'GWYNETH ANNE',
#                 'VesselType': 31.0,
#                 'Width': None},
#  'type': 'Feature'}
# {'geometry': {'coordinates': [-87.67641, 41.84032], 'type': 'Point'},
#  'properties': {'BaseDateTime': '2020-12-31 21:48:10',
#                 'COG': 72.3,
#                 'CallSign': 'WDJ6110',
#                 'Cargo': None,
#                 'Draft': None,
#                 'Heading': 511.0,
#                 'IMO': None,
#                 'LAT': 41.84032,
#                 'LON': -87.67641,
#                 'Length': None,
#                 'MMSI': 367794470,
#                 'SOG': 0.0,
#                 'Status': 15.0,
#                 'TransceiverClass': 'A',
#                 'VesselName': 'GWYNETH ANNE',
#                 'VesselType': 31.0,
#                 'Width': None},
#  'type': 'Feature'}
# {'geometry': {'coordinates': [-87.67878, 41.83973], 'type': 'Point'},
#  'properties': {'BaseDateTime': '2020-12-31 14:37:01',
#                 'COG': 108.9,
#                 'CallSign': 'WDJ6110',
#                 'Cargo': None,
#                 'Draft': None,
#                 'Heading': 72.0,
#                 'IMO': None,
#                 'LAT': 41.83973,
#                 'LON': -87.67878,
#                 'Length': None,
#                 'MMSI': 367794470,
#                 'SOG': 0.0,
#                 'Status': 15.0,
#                 'TransceiverClass': 'A',
#                 'VesselName': 'GWYNETH ANNE',
#                 'VesselType': 31.0,
#                 'Width': None},
#  'type': 'Feature'}
# {'geometry': {'coordinates': [-87.67638, 41.84031], 'type': 'Point'},
#  'properties': {'BaseDateTime': '2020-12-31 21:49:20',
#                 'COG': 249.0,
#                 'CallSign': 'WDJ6110',
#                 'Cargo': None,
#                 'Draft': None,
#                 'Heading': 511.0,
#                 'IMO': None,
#                 'LAT': 41.84031,
#                 'LON': -87.67638,
#                 'Length': None,
#                 'MMSI': 367794470,
#                 'SOG': 0.0,
#                 'Status': 15.0,
#                 'TransceiverClass': 'A',
#                 'VesselName': 'GWYNETH ANNE',
#                 'VesselType': 31.0,
#                 'Width': None},
#  'type': 'Feature'}
# {'geometry': {'coordinates': [-87.67637, 41.84031], 'type': 'Point'},
#  'properties': {'BaseDateTime': '2020-12-31 21:51:50',
#                 'COG': 171.1,
#                 'CallSign': 'WDJ6110',
#                 'Cargo': None,
#                 'Draft': None,
#                 'Heading': 511.0,
#                 'IMO': None,
#                 'LAT': 41.84031,
#                 'LON': -87.67637,
#                 'Length': None,
#                 'MMSI': 367794470,
#                 'SOG': 0.0,
#                 'Status': 15.0,
#                 'TransceiverClass': 'A',
#                 'VesselName': 'GWYNETH ANNE',
#                 'VesselType': 31.0,
#                 'Width': None},
#  'type': 'Feature'}
# {'geometry': {'coordinates': [-87.67638, 41.8403], 'type': 'Point'},
#  'properties': {'BaseDateTime': '2020-12-31 21:50:30',
#                 'COG': 162.6,
#                 'CallSign': 'WDJ6110',
#                 'Cargo': None,
#                 'Draft': None,
#                 'Heading': 511.0,
#                 'IMO': None,
#                 'LAT': 41.8403,
#                 'LON': -87.67638,
#                 'Length': None,
#                 'MMSI': 367794470,
#                 'SOG': 0.2,
#                 'Status': 15.0,
#                 'TransceiverClass': 'A',
#                 'VesselName': 'GWYNETH ANNE',
#                 'VesselType': 31.0,
#                 'Width': None},
#  'type': 'Feature'}
# {'geometry': {'coordinates': [-87.67877, 41.83971], 'type': 'Point'},
#  'properties': {'BaseDateTime': '2020-12-31 14:35:53',
#                 'COG': 352.6,
#                 'CallSign': 'WDJ6110',
#                 'Cargo': None,
#                 'Draft': None,
#                 'Heading': 70.0,
#                 'IMO': None,
#                 'LAT': 41.83971,
#                 'LON': -87.67877,
#                 'Length': None,
#                 'MMSI': 367794470,
#                 'SOG': 0.3,
#                 'Status': 15.0,
#                 'TransceiverClass': 'A',
#                 'VesselName': 'GWYNETH ANNE',
#                 'VesselType': 31.0,
#                 'Width': None},
#  'type': 'Feature'}
# {'geometry': {'coordinates': [-87.67875, 41.8397], 'type': 'Point'},
#  'properties': {'BaseDateTime': '2020-12-31 14:41:43',
#                 'COG': 342.3,
#                 'CallSign': 'WDJ6110',
#                 'Cargo': None,
#                 'Draft': None,
#                 'Heading': 72.0,
#                 'IMO': None,
#                 'LAT': 41.8397,
#                 'LON': -87.67875,
#                 'Length': None,
#                 'MMSI': 367794470,
#                 'SOG': 0.2,
#                 'Status': 15.0,
#                 'TransceiverClass': 'A',
#                 'VesselName': 'GWYNETH ANNE',
#                 'VesselType': 31.0,
#                 'Width': None},
#  'type': 'Feature'}
# {'geometry': {'coordinates': [-87.67875, 41.83968], 'type': 'Point'},
#  'properties': {'BaseDateTime': '2020-12-31 14:38:13',
#                 'COG': 149.8,
#                 'CallSign': 'WDJ6110',
#                 'Cargo': None,
#                 'Draft': None,
#                 'Heading': 68.0,
#                 'IMO': None,
#                 'LAT': 41.83968,
#                 'LON': -87.67875,
#                 'Length': None,
#                 'MMSI': 367794470,
#                 'SOG': 0.2,
#                 'Status': 15.0,
#                 'TransceiverClass': 'A',
#                 'VesselName': 'GWYNETH ANNE',
#                 'VesselType': 31.0,
#                 'Width': None},
#  'type': 'Feature'}
# {'geometry': {'coordinates': [-87.67224, 41.84306], 'type': 'Point'},
#  'properties': {'BaseDateTime': '2020-12-31 14:49:21',
#                 'COG': 59.9,
#                 'CallSign': 'WDJ6110',
#                 'Cargo': None,
#                 'Draft': None,
#                 'Heading': 60.0,
#                 'IMO': None,
#                 'LAT': 41.84306,
#                 'LON': -87.67224,
#                 'Length': None,
#                 'MMSI': 367794470,
#                 'SOG': 4.0,
#                 'Status': 15.0,
#                 'TransceiverClass': 'A',
#                 'VesselName': 'GWYNETH ANNE',
#                 'VesselType': 31.0,
#                 'Width': None},
#  'type': 'Feature'}
# {'geometry': {'coordinates': [-87.67876, 41.83965], 'type': 'Point'},
#  'properties': {'BaseDateTime': '2020-12-31 14:39:22',
#                 'COG': 194.2,
#                 'CallSign': 'WDJ6110',
#                 'Cargo': None,
#                 'Draft': None,
#                 'Heading': 69.0,
#                 'IMO': None,
#                 'LAT': 41.83965,
#                 'LON': -87.67876,
#                 'Length': None,
#                 'MMSI': 367794470,
#                 'SOG': 0.0,
#                 'Status': 15.0,
#                 'TransceiverClass': 'A',
#                 'VesselName': 'GWYNETH ANNE',
#                 'VesselType': 31.0,
#                 'Width': None},
#  'type': 'Feature'}
# {'geometry': {'coordinates': [-87.67875, 41.83965], 'type': 'Point'},
#  'properties': {'BaseDateTime': '2020-12-31 14:40:33',
#                 'COG': 11.6,
#                 'CallSign': 'WDJ6110',
#                 'Cargo': None,
#                 'Draft': None,
#                 'Heading': 70.0,
#                 'IMO': None,
#                 'LAT': 41.83965,
#                 'LON': -87.67875,
#                 'Length': None,
#                 'MMSI': 367794470,
#                 'SOG': 0.1,
#                 'Status': 15.0,
#                 'TransceiverClass': 'A',
#                 'VesselName': 'GWYNETH ANNE',
#                 'VesselType': 31.0,
#                 'Width': None},
#  'type': 'Feature'}
# {'geometry': {'coordinates': [-87.67897, 41.83961], 'type': 'Point'},
#  'properties': {'BaseDateTime': '2020-12-31 14:34:42',
#                 'COG': 72.4,
#                 'CallSign': 'WDJ6110',
#                 'Cargo': None,
#                 'Draft': None,
#                 'Heading': 68.0,
#                 'IMO': None,
#                 'LAT': 41.83961,
#                 'LON': -87.67897,
#                 'Length': None,
#                 'MMSI': 367794470,
#                 'SOG': 1.1,
#                 'Status': 15.0,
#                 'TransceiverClass': 'A',
#                 'VesselName': 'GWYNETH ANNE',
#                 'VesselType': 31.0,
#                 'Width': None},
#  'type': 'Feature'}
# {'geometry': {'coordinates': [-87.67881, 41.83961], 'type': 'Point'},
#  'properties': {'BaseDateTime': '2020-12-31 14:42:44',
#                 'COG': 171.7,
#                 'CallSign': 'WDJ6110',
#                 'Cargo': None,
#                 'Draft': None,
#                 'Heading': 58.0,
#                 'IMO': None,
#                 'LAT': 41.83961,
#                 'LON': -87.67881,
#                 'Length': None,
#                 'MMSI': 367794470,
#                 'SOG': 0.4,
#                 'Status': 15.0,
#                 'TransceiverClass': 'A',
#                 'VesselName': 'GWYNETH ANNE',
#                 'VesselType': 31.0,
#                 'Width': None},
#  'type': 'Feature'}
# {'geometry': {'coordinates': [-87.67949, 41.83953], 'type': 'Point'},
#  'properties': {'BaseDateTime': '2020-12-31 14:33:41',
#                 'COG': 75.1,
#                 'CallSign': 'WDJ6110',
#                 'Cargo': None,
#                 'Draft': None,
#                 'Heading': 70.0,
#                 'IMO': None,
#                 'LAT': 41.83953,
#                 'LON': -87.67949,
#                 'Length': None,
#                 'MMSI': 367794470,
#                 'SOG': 1.7,
#                 'Status': 15.0,
#                 'TransceiverClass': 'A',
#                 'VesselName': 'GWYNETH ANNE',
#                 'VesselType': 31.0,
#                 'Width': None},
#  'type': 'Feature'}
# {'geometry': {'coordinates': [-87.68018, 41.83942], 'type': 'Point'},
#  'properties': {'BaseDateTime': '2020-12-31 22:59:02',
#                 'COG': 64.8,
#                 'CallSign': 'WDH6184',
#                 'Cargo': None,
#                 'Draft': None,
#                 'Heading': 65.0,
#                 'IMO': None,
#                 'LAT': 41.83942,
#                 'LON': -87.68018,
#                 'Length': 22.0,
#                 'MMSI': 367635370,
#                 'SOG': 5.7,
#                 'Status': 15.0,
#                 'TransceiverClass': 'A',
#                 'VesselName': 'SYDNEY REESE',
#                 'VesselType': 31.0,
#                 'Width': None},
#  'type': 'Feature'}
# {'geometry': {'coordinates': [-87.68037, 41.83929], 'type': 'Point'},
#  'properties': {'BaseDateTime': '2020-12-31 14:32:32',
#                 'COG': 66.8,
#                 'CallSign': 'WDJ6110',
#                 'Cargo': None,
#                 'Draft': None,
#                 'Heading': 71.0,
#                 'IMO': None,
#                 'LAT': 41.83929,
#                 'LON': -87.68037,
#                 'Length': None,
#                 'MMSI': 367794470,
#                 'SOG': 2.9,
#                 'Status': 15.0,
#                 'TransceiverClass': 'A',
#                 'VesselName': 'GWYNETH ANNE',
#                 'VesselType': 31.0,
#                 'Width': None},
#  'type': 'Feature'}
# {'geometry': {'coordinates': [-87.67154, 41.8434], 'type': 'Point'},
#  'properties': {'BaseDateTime': '2020-12-31 23:47:05',
#                 'COG': 242.7,
#                 'CallSign': 'WDH6184',
#                 'Cargo': None,
#                 'Draft': None,
#                 'Heading': 242.0,
#                 'IMO': None,
#                 'LAT': 41.8434,
#                 'LON': -87.67154,
#                 'Length': 22.0,
#                 'MMSI': 367635370,
#                 'SOG': 5.4,
#                 'Status': 15.0,
#                 'TransceiverClass': 'A',
#                 'VesselName': 'SYDNEY REESE',
#                 'VesselType': 31.0,
#                 'Width': None},
#  'type': 'Feature'}
# {'geometry': {'coordinates': [-87.68071, 41.83927], 'type': 'Point'},
#  'properties': {'BaseDateTime': '2020-12-31 20:23:40',
#                 'COG': 247.9,
#                 'CallSign': 'WDJ6110',
#                 'Cargo': None,
#                 'Draft': None,
#                 'Heading': 511.0,
#                 'IMO': None,
#                 'LAT': 41.83927,
#                 'LON': -87.68071,
#                 'Length': None,
#                 'MMSI': 367794470,
#                 'SOG': 6.1,
#                 'Status': 15.0,
#                 'TransceiverClass': 'A',
#                 'VesselName': 'GWYNETH ANNE',
#                 'VesselType': 31.0,
#                 'Width': None},
#  'type': 'Feature'}
# {'geometry': {'coordinates': [-87.67146, 41.84339], 'type': 'Point'},
#  'properties': {'BaseDateTime': '2020-12-31 20:18:50',
#                 'COG': 245.4,
#                 'CallSign': 'WDJ6110',
#                 'Cargo': None,
#                 'Draft': None,
#                 'Heading': 511.0,
#                 'IMO': None,
#                 'LAT': 41.84339,
#                 'LON': -87.67146,
#                 'Length': None,
#                 'MMSI': 367794470,
#                 'SOG': 6.1,
#                 'Status': 15.0,
#                 'TransceiverClass': 'A',
#                 'VesselName': 'GWYNETH ANNE',
#                 'VesselType': 31.0,
#                 'Width': None},
#  'type': 'Feature'}
# {'geometry': {'coordinates': [-87.6814, 41.8391], 'type': 'Point'},
#  'properties': {'BaseDateTime': '2020-12-31 21:44:41',
#                 'COG': 67.8,
#                 'CallSign': 'WDJ6110',
#                 'Cargo': None,
#                 'Draft': None,
#                 'Heading': 511.0,
#                 'IMO': None,
#                 'LAT': 41.8391,
#                 'LON': -87.6814,
#                 'Length': None,
#                 'MMSI': 367794470,
#                 'SOG': 6.0,
#                 'Status': 15.0,
#                 'TransceiverClass': 'A',
#                 'VesselName': 'GWYNETH ANNE',
#                 'VesselType': 31.0,
#                 'Width': None},
#  'type': 'Feature'}
# {'geometry': {'coordinates': [-87.67105, 41.84354], 'type': 'Point'},
#  'properties': {'BaseDateTime': '2020-12-31 22:03:31',
#                 'COG': 64.1,
#                 'CallSign': 'WDJ6110',
#                 'Cargo': None,
#                 'Draft': None,
#                 'Heading': 511.0,
#                 'IMO': None,
#                 'LAT': 41.84354,
#                 'LON': -87.67105,
#                 'Length': None,
#                 'MMSI': 367794470,
#                 'SOG': 3.5,
#                 'Status': 15.0,
#                 'TransceiverClass': 'A',
#                 'VesselName': 'GWYNETH ANNE',
#                 'VesselType': 31.0,
#                 'Width': None},
#  'type': 'Feature'}
# {'geometry': {'coordinates': [-87.67084, 41.84364], 'type': 'Point'},
#  'properties': {'BaseDateTime': '2020-12-31 14:50:33',
#                 'COG': 61.9,
#                 'CallSign': 'WDJ6110',
#                 'Cargo': None,
#                 'Draft': None,
#                 'Heading': 68.0,
#                 'IMO': None,
#                 'LAT': 41.84364,
#                 'LON': -87.67084,
#                 'Length': None,
#                 'MMSI': 367794470,
#                 'SOG': 3.4,
#                 'Status': 15.0,
#                 'TransceiverClass': 'A',
#                 'VesselName': 'GWYNETH ANNE',
#                 'VesselType': 31.0,
#                 'Width': None},
#  'type': 'Feature'}
# {'geometry': {'coordinates': [-87.6816, 41.83889], 'type': 'Point'},
#  'properties': {'BaseDateTime': '2020-12-31 14:31:22',
#                 'COG': 66.3,
#                 'CallSign': 'WDJ6110',
#                 'Cargo': None,
#                 'Draft': None,
#                 'Heading': 67.0,
#                 'IMO': None,
#                 'LAT': 41.83889,
#                 'LON': -87.6816,
#                 'Length': None,
#                 'MMSI': 367794470,
#                 'SOG': 3.5,
#                 'Status': 15.0,
#                 'TransceiverClass': 'A',
#                 'VesselName': 'GWYNETH ANNE',
#                 'VesselType': 31.0,
#                 'Width': None},
#  'type': 'Feature'}
# {'geometry': {'coordinates': [-87.68222, 41.83875], 'type': 'Point'},
#  'properties': {'BaseDateTime': '2020-12-31 22:57:59',
#                 'COG': 70.1,
#                 'CallSign': 'WDH6184',
#                 'Cargo': None,
#                 'Draft': None,
#                 'Heading': 71.0,
#                 'IMO': None,
#                 'LAT': 41.83875,
#                 'LON': -87.68222,
#                 'Length': 22.0,
#                 'MMSI': 367635370,
#                 'SOG': 5.7,
#                 'Status': 15.0,
#                 'TransceiverClass': 'A',
#                 'VesselName': 'SYDNEY REESE',
#                 'VesselType': 31.0,
#                 'Width': None},
#  'type': 'Feature'}
# {'geometry': {'coordinates': [-87.66974, 41.84401], 'type': 'Point'},
#  'properties': {'BaseDateTime': '2020-12-31 22:04:40',
#                 'COG': 65.9,
#                 'CallSign': 'WDJ6110',
#                 'Cargo': None,
#                 'Draft': None,
#                 'Heading': 511.0,
#                 'IMO': None,
#                 'LAT': 41.84401,
#                 'LON': -87.66974,
#                 'Length': None,
#                 'MMSI': 367794470,
#                 'SOG': 3.2,
#                 'Status': 15.0,
#                 'TransceiverClass': 'A',
#                 'VesselName': 'GWYNETH ANNE',
#                 'VesselType': 31.0,
#                 'Width': None},
#  'type': 'Feature'}
# {'geometry': {'coordinates': [-87.68319, 41.83849], 'type': 'Point'},
#  'properties': {'BaseDateTime': '2020-12-31 20:24:51',
#                 'COG': 247.0,
#                 'CallSign': 'WDJ6110',
#                 'Cargo': None,
#                 'Draft': None,
#                 'Heading': 511.0,
#                 'IMO': None,
#                 'LAT': 41.83849,
#                 'LON': -87.68319,
#                 'Length': None,
#                 'MMSI': 367794470,
#                 'SOG': 6.2,
#                 'Status': 15.0,
#                 'TransceiverClass': 'A',
#                 'VesselName': 'GWYNETH ANNE',
#                 'VesselType': 31.0,
#                 'Width': None},
#  'type': 'Feature'}
# {'geometry': {'coordinates': [-87.68305, 41.83839], 'type': 'Point'},
#  'properties': {'BaseDateTime': '2020-12-31 14:30:13',
#                 'COG': 70.7,
#                 'CallSign': 'WDJ6110',
#                 'Cargo': None,
#                 'Draft': None,
#                 'Heading': 68.0,
#                 'IMO': None,
#                 'LAT': 41.83839,
#                 'LON': -87.68305,
#                 'Length': None,
#                 'MMSI': 367794470,
#                 'SOG': 3.7,
#                 'Status': 15.0,
#                 'TransceiverClass': 'A',
#                 'VesselName': 'GWYNETH ANNE',
#                 'VesselType': 31.0,
#                 'Width': None},
#  'type': 'Feature'}
# {'geometry': {'coordinates': [-87.66951, 41.84405], 'type': 'Point'},
#  'properties': {'BaseDateTime': '2020-12-31 14:51:42',
#                 'COG': 66.6,
#                 'CallSign': 'WDJ6110',
#                 'Cargo': None,
#                 'Draft': None,
#                 'Heading': 68.0,
#                 'IMO': None,
#                 'LAT': 41.84405,
#                 'LON': -87.66951,
#                 'Length': None,
#                 'MMSI': 367794470,
#                 'SOG': 3.7,
#                 'Status': 15.0,
#                 'TransceiverClass': 'A',
#                 'VesselName': 'GWYNETH ANNE',
#                 'VesselType': 31.0,
#                 'Width': None},
#  'type': 'Feature'}
# {'geometry': {'coordinates': [-87.66914, 41.84426], 'type': 'Point'},
#  'properties': {'BaseDateTime': '2020-12-31 20:17:40',
#                 'COG': 246.6,
#                 'CallSign': 'WDJ6110',
#                 'Cargo': None,
#                 'Draft': None,
#                 'Heading': 511.0,
#                 'IMO': None,
#                 'LAT': 41.84426,
#                 'LON': -87.66914,
#                 'Length': None,
#                 'MMSI': 367794470,
#                 'SOG': 6.0,
#                 'Status': 15.0,
#                 'TransceiverClass': 'A',
#                 'VesselName': 'GWYNETH ANNE',
#                 'VesselType': 31.0,
#                 'Width': None},
#  'type': 'Feature'}
# {'geometry': {'coordinates': [-87.68386, 41.83831], 'type': 'Point'},
#  'properties': {'BaseDateTime': '2020-12-31 21:43:29',
#                 'COG': 67.2,
#                 'CallSign': 'WDJ6110',
#                 'Cargo': None,
#                 'Draft': None,
#                 'Heading': 511.0,
#                 'IMO': None,
#                 'LAT': 41.83831,
#                 'LON': -87.68386,
#                 'Length': None,
#                 'MMSI': 367794470,
#                 'SOG': 6.1,
#                 'Status': 15.0,
#                 'TransceiverClass': 'A',
#                 'VesselName': 'GWYNETH ANNE',
#                 'VesselType': 31.0,
#                 'Width': None},
#  'type': 'Feature'}
# {'geometry': {'coordinates': [-87.68416, 41.83818], 'type': 'Point'},
#  'properties': {'BaseDateTime': '2020-12-31 22:56:55',
#                 'COG': 65.1,
#                 'CallSign': 'WDH6184',
#                 'Cargo': None,
#                 'Draft': None,
#                 'Heading': 66.0,
#                 'IMO': None,
#                 'LAT': 41.83818,
#                 'LON': -87.68416,
#                 'Length': 22.0,
#                 'MMSI': 367635370,
#                 'SOG': 5.6,
#                 'Status': 15.0,
#                 'TransceiverClass': 'A',
#                 'VesselName': 'SYDNEY REESE',
#                 'VesselType': 31.0,
#                 'Width': None},
#  'type': 'Feature'}
# {'geometry': {'coordinates': [-87.66851, 41.84443], 'type': 'Point'},
#  'properties': {'BaseDateTime': '2020-12-31 22:05:49',
#                 'COG': 64.9,
#                 'CallSign': 'WDJ6110',
#                 'Cargo': None,
#                 'Draft': None,
#                 'Heading': 511.0,
#                 'IMO': None,
#                 'LAT': 41.84443,
#                 'LON': -87.66851,
#                 'Length': None,
#                 'MMSI': 367794470,
#                 'SOG': 3.1,
#                 'Status': 15.0,
#                 'TransceiverClass': 'A',
#                 'VesselName': 'GWYNETH ANNE',
#                 'VesselType': 31.0,
#                 'Width': None},
#  'type': 'Feature'}
# {'geometry': {'coordinates': [-87.68461, 41.83804], 'type': 'Point'},
#  'properties': {'BaseDateTime': '2020-12-31 14:29:02',
#                 'COG': 68.9,
#                 'CallSign': 'WDJ6110',
#                 'Cargo': None,
#                 'Draft': None,
#                 'Heading': 71.0,
#                 'IMO': None,
#                 'LAT': 41.83804,
#                 'LON': -87.68461,
#                 'Length': None,
#                 'MMSI': 367794470,
#                 'SOG': 3.7,
#                 'Status': 15.0,
#                 'TransceiverClass': 'A',
#                 'VesselName': 'GWYNETH ANNE',
#                 'VesselType': 31.0,
#                 'Width': None},
#  'type': 'Feature'}
# {'geometry': {'coordinates': [-87.66797, 41.84456], 'type': 'Point'},
#  'properties': {'BaseDateTime': '2020-12-31 23:06:59',
#                 'COG': 68.2,
#                 'CallSign': 'WDH6184',
#                 'Cargo': None,
#                 'Draft': None,
#                 'Heading': 71.0,
#                 'IMO': None,
#                 'LAT': 41.84456,
#                 'LON': -87.66797,
#                 'Length': 22.0,
#                 'MMSI': 367635370,
#                 'SOG': 5.3,
#                 'Status': 15.0,
#                 'TransceiverClass': 'A',
#                 'VesselName': 'SYDNEY REESE',
#                 'VesselType': 31.0,
#                 'Width': None},
#  'type': 'Feature'}
# {'geometry': {'coordinates': [-87.66795, 41.84456], 'type': 'Point'},
#  'properties': {'BaseDateTime': '2020-12-31 14:52:49',
#                 'COG': 68.0,
#                 'CallSign': 'WDJ6110',
#                 'Cargo': None,
#                 'Draft': None,
#                 'Heading': 76.0,
#                 'IMO': None,
#                 'LAT': 41.84456,
#                 'LON': -87.66795,
#                 'Length': None,
#                 'MMSI': 367794470,
#                 'SOG': 4.4,
#                 'Status': 15.0,
#                 'TransceiverClass': 'A',
#                 'VesselName': 'GWYNETH ANNE',
#                 'VesselType': 31.0,
#                 'Width': None},
#  'type': 'Feature'}
# {'geometry': {'coordinates': [-87.6856, 41.83769], 'type': 'Point'},
#  'properties': {'BaseDateTime': '2020-12-31 20:26:01',
#                 'COG': 248.0,
#                 'CallSign': 'WDJ6110',
#                 'Cargo': None,
#                 'Draft': None,
#                 'Heading': 511.0,
#                 'IMO': None,
#                 'LAT': 41.83769,
#                 'LON': -87.6856,
#                 'Length': None,
#                 'MMSI': 367794470,
#                 'SOG': 6.0,
#                 'Status': 15.0,
#                 'TransceiverClass': 'A',
#                 'VesselName': 'GWYNETH ANNE',
#                 'VesselType': 31.0,
#                 'Width': None},
#  'type': 'Feature'}
# {'geometry': {'coordinates': [-87.66726, 41.84481], 'type': 'Point'},
#  'properties': {'BaseDateTime': '2020-12-31 22:06:59',
#                 'COG': 71.2,
#                 'CallSign': 'WDJ6110',
#                 'Cargo': None,
#                 'Draft': None,
#                 'Heading': 511.0,
#                 'IMO': None,
#                 'LAT': 41.84481,
#                 'LON': -87.66726,
#                 'Length': None,
#                 'MMSI': 367794470,
#                 'SOG': 3.1,
#                 'Status': 15.0,
#                 'TransceiverClass': 'A',
#                 'VesselName': 'GWYNETH ANNE',
#                 'VesselType': 31.0,
#                 'Width': None},
#  'type': 'Feature'}
# {'geometry': {'coordinates': [-87.68608, 41.83754], 'type': 'Point'},
#  'properties': {'BaseDateTime': '2020-12-31 14:27:52',
#                 'COG': 65.5,
#                 'CallSign': 'WDJ6110',
#                 'Cargo': None,
#                 'Draft': None,
#                 'Heading': 69.0,
#                 'IMO': None,
#                 'LAT': 41.83754,
#                 'LON': -87.68608,
#                 'Length': None,
#                 'MMSI': 367794470,
#                 'SOG': 3.6,
#                 'Status': 15.0,
#                 'TransceiverClass': 'A',
#                 'VesselName': 'GWYNETH ANNE',
#                 'VesselType': 31.0,
#                 'Width': None},
#  'type': 'Feature'}
# {'geometry': {'coordinates': [-87.66712, 41.84484], 'type': 'Point'},
#  'properties': {'BaseDateTime': '2020-12-31 23:44:37',
#                 'COG': 254.1,
#                 'CallSign': 'WDH6184',
#                 'Cargo': None,
#                 'Draft': None,
#                 'Heading': 249.0,
#                 'IMO': None,
#                 'LAT': 41.84484,
#                 'LON': -87.66712,
#                 'Length': 22.0,
#                 'MMSI': 367635370,
#                 'SOG': 4.9,
#                 'Status': 15.0,
#                 'TransceiverClass': 'A',
#                 'VesselName': 'SYDNEY REESE',
#                 'VesselType': 31.0,
#                 'Width': None},
#  'type': 'Feature'}
# {'geometry': {'coordinates': [-87.68627, 41.83757], 'type': 'Point'},
#  'properties': {'BaseDateTime': '2020-12-31 21:42:20',
#                 'COG': 62.5,
#                 'CallSign': 'WDJ6110',
#                 'Cargo': None,
#                 'Draft': None,
#                 'Heading': 511.0,
#                 'IMO': None,
#                 'LAT': 41.83757,
#                 'LON': -87.68627,
#                 'Length': None,
#                 'MMSI': 367794470,
#                 'SOG': 6.3,
#                 'Status': 15.0,
#                 'TransceiverClass': 'A',
#                 'VesselName': 'GWYNETH ANNE',
#                 'VesselType': 31.0,
#                 'Width': None},
#  'type': 'Feature'}
# {'geometry': {'coordinates': [-87.68629, 41.8375], 'type': 'Point'},
#  'properties': {'BaseDateTime': '2020-12-31 22:55:54',
#                 'COG': 65.1,
#                 'CallSign': 'WDH6184',
#                 'Cargo': None,
#                 'Draft': None,
#                 'Heading': 67.0,
#                 'IMO': None,
#                 'LAT': 41.8375,
#                 'LON': -87.68629,
#                 'Length': 22.0,
#                 'MMSI': 367635370,
#                 'SOG': 5.6,
#                 'Status': 15.0,
#                 'TransceiverClass': 'A',
#                 'VesselName': 'SYDNEY REESE',
#                 'VesselType': 31.0,
#                 'Width': None},
#  'type': 'Feature'}
# {'geometry': {'coordinates': [-87.66687, 41.84488], 'type': 'Point'},
#  'properties': {'BaseDateTime': '2020-12-31 20:16:31',
#                 'COG': 267.0,
#                 'CallSign': 'WDJ6110',
#                 'Cargo': None,
#                 'Draft': None,
#                 'Heading': 511.0,
#                 'IMO': None,
#                 'LAT': 41.84488,
#                 'LON': -87.66687,
#                 'Length': None,
#                 'MMSI': 367794470,
#                 'SOG': 5.0,
#                 'Status': 15.0,
#                 'TransceiverClass': 'A',
#                 'VesselName': 'GWYNETH ANNE',
#                 'VesselType': 31.0,
#                 'Width': None},
#  'type': 'Feature'}
# {'geometry': {'coordinates': [-87.66629, 41.84488], 'type': 'Point'},
#  'properties': {'BaseDateTime': '2020-12-31 14:53:51',
#                 'COG': 83.2,
#                 'CallSign': 'WDJ6110',
#                 'Cargo': None,
#                 'Draft': None,
#                 'Heading': 95.0,
#                 'IMO': None,
#                 'LAT': 41.84488,
#                 'LON': -87.66629,
#                 'Length': None,
#                 'MMSI': 367794470,
#                 'SOG': 4.5,
#                 'Status': 15.0,
#                 'TransceiverClass': 'A',
#                 'VesselName': 'GWYNETH ANNE',
#                 'VesselType': 31.0,
#                 'Width': None},
#  'type': 'Feature'}
# {'geometry': {'coordinates': [-87.66599, 41.84483], 'type': 'Point'},
#  'properties': {'BaseDateTime': '2020-12-31 22:08:10',
#                 'COG': 38.3,
#                 'CallSign': 'WDJ6110',
#                 'Cargo': None,
#                 'Draft': None,
#                 'Heading': 511.0,
#                 'IMO': None,
#                 'LAT': 41.84483,
#                 'LON': -87.66599,
#                 'Length': None,
#                 'MMSI': 367794470,
#                 'SOG': 2.3,
#                 'Status': 15.0,
#                 'TransceiverClass': 'A',
#                 'VesselName': 'GWYNETH ANNE',
#                 'VesselType': 31.0,
#                 'Width': None},
#  'type': 'Feature'}
# {'geometry': {'coordinates': [-87.68759, 41.83704], 'type': 'Point'},
#  'properties': {'BaseDateTime': '2020-12-31 20:27:09',
#                 'COG': 360.0,
#                 'CallSign': 'WDJ6110',
#                 'Cargo': None,
#                 'Draft': None,
#                 'Heading': 511.0,
#                 'IMO': None,
#                 'LAT': 41.83704,
#                 'LON': -87.68759,
#                 'Length': None,
#                 'MMSI': 367794470,
#                 'SOG': 102.3,
#                 'Status': 15.0,
#                 'TransceiverClass': 'A',
#                 'VesselName': 'GWYNETH ANNE',
#                 'VesselType': 31.0,
#                 'Width': None},
#  'type': 'Feature'}
# {'geometry': {'coordinates': [-87.68774, 41.837], 'type': 'Point'},
#  'properties': {'BaseDateTime': '2020-12-31 14:26:42',
#                 'COG': 360.0,
#                 'CallSign': 'WDJ6110',
#                 'Cargo': None,
#                 'Draft': None,
#                 'Heading': 67.0,
#                 'IMO': None,
#                 'LAT': 41.837,
#                 'LON': -87.68774,
#                 'Length': None,
#                 'MMSI': 367794470,
#                 'SOG': 102.3,
#                 'Status': 15.0,
#                 'TransceiverClass': 'A',
#                 'VesselName': 'GWYNETH ANNE',
#                 'VesselType': 31.0,
#                 'Width': None},
#  'type': 'Feature'}
# {'geometry': {'coordinates': [-87.66516, 41.84485], 'type': 'Point'},
#  'properties': {'BaseDateTime': '2020-12-31 23:43:32',
#                 'COG': 279.0,
#                 'CallSign': 'WDH6184',
#                 'Cargo': None,
# ...
#                 'TransceiverClass': 'A',
#                 'VesselName': 'GWYNETH ANNE',
#                 'VesselType': 31.0,
#                 'Width': None},
#  'type': 'Feature'}
# {'geometry': {'coordinates': [-87.66536, 41.91845], 'type': 'Point'},
#  'properties': {'BaseDateTime': '2020-12-31 18:42:33',
#                 'COG': 133.2,
#                 'CallSign': 'WDJ6110',
#                 'Cargo': None,
#                 'Draft': None,
#                 'Heading': 511.0,
#                 'IMO': None,
#                 'LAT': 41.91845,
#                 'LON': -87.66536,
#                 'Length': None,
#                 'MMSI': 367794470,
#                 'SOG': 0.0,
#                 'Status': 15.0,
#                 'TransceiverClass': 'A',
#                 'VesselName': 'GWYNETH ANNE',
#                 'VesselType': 31.0,
#                 'Width': None},
#  'type': 'Feature'}
# {'geometry': {'coordinates': [-87.66536, 41.91845], 'type': 'Point'},
#  'properties': {'BaseDateTime': '2020-12-31 18:36:44',
#                 'COG': 215.5,
#                 'CallSign': 'WDJ6110',
#                 'Cargo': None,
#                 'Draft': None,
#                 'Heading': 511.0,
#                 'IMO': None,
#                 'LAT': 41.91845,
#                 'LON': -87.66536,
#                 'Length': None,
#                 'MMSI': 367794470,
#                 'SOG': 0.0,
#                 'Status': 15.0,
#                 'TransceiverClass': 'A',
#                 'VesselName': 'GWYNETH ANNE',
#                 'VesselType': 31.0,
#                 'Width': None},
#  'type': 'Feature'}
# {'geometry': {'coordinates': [-87.66536, 41.91845], 'type': 'Point'},
#  'properties': {'BaseDateTime': '2020-12-31 18:39:03',
#                 'COG': 315.1,
#                 'CallSign': 'WDJ6110',
#                 'Cargo': None,
#                 'Draft': None,
#                 'Heading': 511.0,
#                 'IMO': None,
#                 'LAT': 41.91845,
#                 'LON': -87.66536,
#                 'Length': None,
#                 'MMSI': 367794470,
#                 'SOG': 0.0,
#                 'Status': 15.0,
#                 'TransceiverClass': 'A',
#                 'VesselName': 'GWYNETH ANNE',
#                 'VesselType': 31.0,
#                 'Width': None},
#  'type': 'Feature'}
# {'geometry': {'coordinates': [-87.66536, 41.91845], 'type': 'Point'},
#  'properties': {'BaseDateTime': '2020-12-31 18:11:24',
#                 'COG': 196.7,
#                 'CallSign': 'WDJ6110',
#                 'Cargo': None,
#                 'Draft': None,
#                 'Heading': 511.0,
#                 'IMO': None,
#                 'LAT': 41.91845,
#                 'LON': -87.66536,
#                 'Length': None,
#                 'MMSI': 367794470,
#                 'SOG': 0.0,
#                 'Status': 15.0,
#                 'TransceiverClass': 'A',
#                 'VesselName': 'GWYNETH ANNE',
#                 'VesselType': 31.0,
#                 'Width': None},
#  'type': 'Feature'}
# {'geometry': {'coordinates': [-87.66536, 41.91845], 'type': 'Point'},
#  'properties': {'BaseDateTime': '2020-12-31 18:18:04',
#                 'COG': 6.8,
#                 'CallSign': 'WDJ6110',
#                 'Cargo': None,
#                 'Draft': None,
#                 'Heading': 511.0,
#                 'IMO': None,
#                 'LAT': 41.91845,
#                 'LON': -87.66536,
#                 'Length': None,
#                 'MMSI': 367794470,
#                 'SOG': 0.0,
#                 'Status': 15.0,
#                 'TransceiverClass': 'A',
#                 'VesselName': 'GWYNETH ANNE',
#                 'VesselType': 31.0,
#                 'Width': None},
#  'type': 'Feature'}
# {'geometry': {'coordinates': [-87.66536, 41.91845], 'type': 'Point'},
#  'properties': {'BaseDateTime': '2020-12-31 17:49:54',
#                 'COG': 333.1,
#                 'CallSign': 'WDJ6110',
#                 'Cargo': None,
#                 'Draft': None,
#                 'Heading': 511.0,
#                 'IMO': None,
#                 'LAT': 41.91845,
#                 'LON': -87.66536,
#                 'Length': None,
#                 'MMSI': 367794470,
#                 'SOG': 0.0,
#                 'Status': 15.0,
#                 'TransceiverClass': 'A',
#                 'VesselName': 'GWYNETH ANNE',
#                 'VesselType': 31.0,
#                 'Width': None},
#  'type': 'Feature'}
# {'geometry': {'coordinates': [-87.66536, 41.91845], 'type': 'Point'},
#  'properties': {'BaseDateTime': '2020-12-31 18:10:23',
#                 'COG': 245.4,
#                 'CallSign': 'WDJ6110',
#                 'Cargo': None,
#                 'Draft': None,
#                 'Heading': 511.0,
#                 'IMO': None,
#                 'LAT': 41.91845,
#                 'LON': -87.66536,
#                 'Length': None,
#                 'MMSI': 367794470,
#                 'SOG': 0.0,
#                 'Status': 15.0,
#                 'TransceiverClass': 'A',
#                 'VesselName': 'GWYNETH ANNE',
#                 'VesselType': 31.0,
#                 'Width': None},
#  'type': 'Feature'}
# {'geometry': {'coordinates': [-87.66536, 41.91845], 'type': 'Point'},
#  'properties': {'BaseDateTime': '2020-12-31 17:42:54',
#                 'COG': 340.6,
#                 'CallSign': 'WDJ6110',
#                 'Cargo': None,
#                 'Draft': None,
#                 'Heading': 511.0,
#                 'IMO': None,
#                 'LAT': 41.91845,
#                 'LON': -87.66536,
#                 'Length': None,
#                 'MMSI': 367794470,
#                 'SOG': 0.0,
#                 'Status': 15.0,
#                 'TransceiverClass': 'A',
#                 'VesselName': 'GWYNETH ANNE',
#                 'VesselType': 31.0,
#                 'Width': None},
#  'type': 'Feature'}
# {'geometry': {'coordinates': [-87.66535, 41.91845], 'type': 'Point'},
#  'properties': {'BaseDateTime': '2020-12-31 18:23:55',
#                 'COG': 289.6,
#                 'CallSign': 'WDJ6110',
#                 'Cargo': None,
#                 'Draft': None,
#                 'Heading': 511.0,
#                 'IMO': None,
#                 'LAT': 41.91845,
#                 'LON': -87.66535,
#                 'Length': None,
#                 'MMSI': 367794470,
#                 'SOG': 0.0,
#                 'Status': 15.0,
#                 'TransceiverClass': 'A',
#                 'VesselName': 'GWYNETH ANNE',
#                 'VesselType': 31.0,
#                 'Width': None},
#  'type': 'Feature'}
# {'geometry': {'coordinates': [-87.66535, 41.91845], 'type': 'Point'},
#  'properties': {'BaseDateTime': '2020-12-31 18:08:04',
#                 'COG': 86.8,
#                 'CallSign': 'WDJ6110',
#                 'Cargo': None,
#                 'Draft': None,
#                 'Heading': 511.0,
#                 'IMO': None,
#                 'LAT': 41.91845,
#                 'LON': -87.66535,
#                 'Length': None,
#                 'MMSI': 367794470,
#                 'SOG': 0.0,
#                 'Status': 15.0,
#                 'TransceiverClass': 'A',
#                 'VesselName': 'GWYNETH ANNE',
#                 'VesselType': 31.0,
#                 'Width': None},
#  'type': 'Feature'}
# {'geometry': {'coordinates': [-87.66535, 41.91845], 'type': 'Point'},
#  'properties': {'BaseDateTime': '2020-12-31 17:38:14',
#                 'COG': 323.8,
#                 'CallSign': 'WDJ6110',
#                 'Cargo': None,
#                 'Draft': None,
#                 'Heading': 511.0,
#                 'IMO': None,
#                 'LAT': 41.91845,
#                 'LON': -87.66535,
#                 'Length': None,
#                 'MMSI': 367794470,
#                 'SOG': 0.0,
#                 'Status': 15.0,
#                 'TransceiverClass': 'A',
#                 'VesselName': 'GWYNETH ANNE',
#                 'VesselType': 31.0,
#                 'Width': None},
#  'type': 'Feature'}
# {'geometry': {'coordinates': [-87.66539, 41.91846], 'type': 'Point'},
#  'properties': {'BaseDateTime': '2020-12-31 17:59:04',
#                 'COG': 140.2,
#                 'CallSign': 'WDJ6110',
#                 'Cargo': None,
#                 'Draft': None,
#                 'Heading': 511.0,
#                 'IMO': None,
#                 'LAT': 41.91846,
#                 'LON': -87.66539,
#                 'Length': None,
#                 'MMSI': 367794470,
#                 'SOG': 0.0,
#                 'Status': 15.0,
#                 'TransceiverClass': 'A',
#                 'VesselName': 'GWYNETH ANNE',
#                 'VesselType': 31.0,
#                 'Width': None},
#  'type': 'Feature'}
# {'geometry': {'coordinates': [-87.66538, 41.91846], 'type': 'Point'},
#  'properties': {'BaseDateTime': '2020-12-31 17:22:14',
#                 'COG': 241.6,
#                 'CallSign': 'WDJ6110',
#                 'Cargo': None,
#                 'Draft': None,
#                 'Heading': 511.0,
#                 'IMO': None,
#                 'LAT': 41.91846,
#                 'LON': -87.66538,
#                 'Length': None,
#                 'MMSI': 367794470,
#                 'SOG': 0.0,
#                 'Status': 15.0,
#                 'TransceiverClass': 'A',
#                 'VesselName': 'GWYNETH ANNE',
#                 'VesselType': 31.0,
#                 'Width': None},
#  'type': 'Feature'}
# {'geometry': {'coordinates': [-87.66538, 41.91846], 'type': 'Point'},
#  'properties': {'BaseDateTime': '2020-12-31 17:21:05',
#                 'COG': 233.7,
#                 'CallSign': 'WDJ6110',
#                 'Cargo': None,
#                 'Draft': None,
#                 'Heading': 511.0,
#                 'IMO': None,
#                 'LAT': 41.91846,
#                 'LON': -87.66538,
#                 'Length': None,
#                 'MMSI': 367794470,
#                 'SOG': 0.0,
#                 'Status': 15.0,
#                 'TransceiverClass': 'A',
#                 'VesselName': 'GWYNETH ANNE',
#                 'VesselType': 31.0,
#                 'Width': None},
#  'type': 'Feature'}
# {'geometry': {'coordinates': [-87.66538, 41.91846], 'type': 'Point'},
#  'properties': {'BaseDateTime': '2020-12-31 17:18:44',
#                 'COG': 301.5,
#                 'CallSign': 'WDJ6110',
#                 'Cargo': None,
#                 'Draft': None,
#                 'Heading': 511.0,
#                 'IMO': None,
#                 'LAT': 41.91846,
#                 'LON': -87.66538,
#                 'Length': None,
#                 'MMSI': 367794470,
#                 'SOG': 0.0,
#                 'Status': 15.0,
#                 'TransceiverClass': 'A',
#                 'VesselName': 'GWYNETH ANNE',
#                 'VesselType': 31.0,
#                 'Width': None},
#  'type': 'Feature'}
# {'geometry': {'coordinates': [-87.66537, 41.91846], 'type': 'Point'},
#  'properties': {'BaseDateTime': '2020-12-31 18:46:03',
#                 'COG': 296.8,
#                 'CallSign': 'WDJ6110',
#                 'Cargo': None,
#                 'Draft': None,
#                 'Heading': 511.0,
#                 'IMO': None,
#                 'LAT': 41.91846,
#                 'LON': -87.66537,
#                 'Length': None,
#                 'MMSI': 367794470,
#                 'SOG': 0.0,
#                 'Status': 15.0,
#                 'TransceiverClass': 'A',
#                 'VesselName': 'GWYNETH ANNE',
#                 'VesselType': 31.0,
#                 'Width': None},
#  'type': 'Feature'}
# {'geometry': {'coordinates': [-87.66537, 41.91846], 'type': 'Point'},
#  'properties': {'BaseDateTime': '2020-12-31 18:44:54',
#                 'COG': 282.7,
#                 'CallSign': 'WDJ6110',
#                 'Cargo': None,
#                 'Draft': None,
#                 'Heading': 511.0,
#                 'IMO': None,
#                 'LAT': 41.91846,
#                 'LON': -87.66537,
#                 'Length': None,
#                 'MMSI': 367794470,
#                 'SOG': 0.1,
#                 'Status': 15.0,
#                 'TransceiverClass': 'A',
#                 'VesselName': 'GWYNETH ANNE',
#                 'VesselType': 31.0,
#                 'Width': None},
#  'type': 'Feature'}
# {'geometry': {'coordinates': [-87.66537, 41.91846], 'type': 'Point'},
#  'properties': {'BaseDateTime': '2020-12-31 18:25:04',
#                 'COG': 298.2,
#                 'CallSign': 'WDJ6110',
#                 'Cargo': None,
#                 'Draft': None,
#                 'Heading': 511.0,
#                 'IMO': None,
#                 'LAT': 41.91846,
#                 'LON': -87.66537,
#                 'Length': None,
#                 'MMSI': 367794470,
#                 'SOG': 0.0,
#                 'Status': 15.0,
#                 'TransceiverClass': 'A',
#                 'VesselName': 'GWYNETH ANNE',
#                 'VesselType': 31.0,
#                 'Width': None},
#  'type': 'Feature'}
# {'geometry': {'coordinates': [-87.66537, 41.91846], 'type': 'Point'},
#  'properties': {'BaseDateTime': '2020-12-31 18:26:13',
#                 'COG': 347.3,
#                 'CallSign': 'WDJ6110',
#                 'Cargo': None,
#                 'Draft': None,
#                 'Heading': 511.0,
#                 'IMO': None,
#                 'LAT': 41.91846,
#                 'LON': -87.66537,
#                 'Length': None,
#                 'MMSI': 367794470,
#                 'SOG': 0.0,
#                 'Status': 15.0,
#                 'TransceiverClass': 'A',
#                 'VesselName': 'GWYNETH ANNE',
#                 'VesselType': 31.0,
#                 'Width': None},
#  'type': 'Feature'}
# {'geometry': {'coordinates': [-87.66537, 41.91846], 'type': 'Point'},
#  'properties': {'BaseDateTime': '2020-12-31 17:56:44',
#                 'COG': 201.2,
#                 'CallSign': 'WDJ6110',
#                 'Cargo': None,
#                 'Draft': None,
#                 'Heading': 511.0,
#                 'IMO': None,
#                 'LAT': 41.91846,
#                 'LON': -87.66537,
#                 'Length': None,
#                 'MMSI': 367794470,
#                 'SOG': 0.0,
#                 'Status': 15.0,
#                 'TransceiverClass': 'A',
#                 'VesselName': 'GWYNETH ANNE',
#                 'VesselType': 31.0,
#                 'Width': None},
#  'type': 'Feature'}
# {'geometry': {'coordinates': [-87.66537, 41.91846], 'type': 'Point'},
#  'properties': {'BaseDateTime': '2020-12-31 18:15:55',
#                 'COG': 254.9,
#                 'CallSign': 'WDJ6110',
#                 'Cargo': None,
#                 'Draft': None,
#                 'Heading': 511.0,
#                 'IMO': None,
#                 'LAT': 41.91846,
#                 'LON': -87.66537,
#                 'Length': None,
#                 'MMSI': 367794470,
#                 'SOG': 0.0,
#                 'Status': 15.0,
#                 'TransceiverClass': 'A',
#                 'VesselName': 'GWYNETH ANNE',
#                 'VesselType': 31.0,
#                 'Width': None},
#  'type': 'Feature'}
# {'geometry': {'coordinates': [-87.66537, 41.91846], 'type': 'Point'},
#  'properties': {'BaseDateTime': '2020-12-31 17:40:35',
#                 'COG': 239.2,
#                 'CallSign': 'WDJ6110',
#                 'Cargo': None,
#                 'Draft': None,
#                 'Heading': 511.0,
#                 'IMO': None,
#                 'LAT': 41.91846,
#                 'LON': -87.66537,
#                 'Length': None,
#                 'MMSI': 367794470,
#                 'SOG': 0.0,
#                 'Status': 15.0,
#                 'TransceiverClass': 'A',
#                 'VesselName': 'GWYNETH ANNE',
#                 'VesselType': 31.0,
#                 'Width': None},
#  'type': 'Feature'}
# {'geometry': {'coordinates': [-87.66536, 41.91846], 'type': 'Point'},
#  'properties': {'BaseDateTime': '2020-12-31 18:09:15',
#                 'COG': 108.4,
#                 'CallSign': 'WDJ6110',
#                 'Cargo': None,
#                 'Draft': None,
#                 'Heading': 511.0,
#                 'IMO': None,
#                 'LAT': 41.91846,
#                 'LON': -87.66536,
#                 'Length': None,
#                 'MMSI': 367794470,
#                 'SOG': 0.0,
#                 'Status': 15.0,
#                 'TransceiverClass': 'A',
#                 'VesselName': 'GWYNETH ANNE',
#                 'VesselType': 31.0,
#                 'Width': None},
#  'type': 'Feature'}

# %%
import folium

CHICAGO_COORDINATES = (41.85, -87.68)

map_attributions = ('&copy; <a href="http://www.openstreetmap.org/copyright">OpenStreetMap</a> '
                    'contributors, &copy; <a href="http://cartodb.com/attributions">CartoDB</a>')

m = folium.Map(location=CHICAGO_COORDINATES,
               # attr=map_attributions,
               # tiles='Cartodb Positron',  #'OpenStreetMap',
               zoom_start=5,
               control_scale=True,
               height=1000,
               width=1000)
for result in results:
    folium.GeoJson(result).add_to(m)

m
